# %%
import tensorflow as tf
from tensorflow.keras import datasets
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, Sequential

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

train_images.shape, train_labels.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
# apply some preprocessing
train_images = train_images.reshape((train_images.shape[0], 28*28))
train_images = train_images / 255.

# %%
model = Sequential([
    Dense(512, activation='relu'),
    Dense(10, activation='sigmoid'),
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
hist = model.fit(
    train_images,
    train_labels,
    batch_size=32,
    epochs=10,
)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2202 - accuracy: 0.9355
# Epoch 2/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0888 - accuracy: 0.9736
# Epoch 3/10
# 1875/1875 [==============================] - 2s 960us/step - loss: 0.0573 - accuracy: 0.9826
# Epoch 4/10
# 1875/1875 [==============================] - 2s 947us/step - loss: 0.0425 - accuracy: 0.9865
# Epoch 5/10
# 1875/1875 [==============================] - 2s 943us/step - loss: 0.0287 - accuracy: 0.9910
# Epoch 6/10
# 1875/1875 [==============================] - 2s 945us/step - loss: 0.0243 - accuracy: 0.9922
# Epoch 7/10
# 1875/1875 [==============================] - 2s 938us/step - loss: 0.0179 - accuracy: 0.9942
# Epoch 8/10
# 1875/1875 [==============================] - 2s 956us/step - loss: 0.0154 - accuracy: 0.9951
# Epoch 9/10
# 1875/1875 [==============================] - 2s 923us/step - loss: 0.0113 - accuracy: 0.9963
# Epoch 10/10
# 1875/1875 [==============================] - 2s 923us/step - loss: 0.0121 - accuracy: 0.9963

# %%
test_images = test_images.reshape((test_images.shape[0], 28*28))
test_images = test_images / 255.

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 0s 996us/step - loss: 0.0764 - accuracy: 0.9821
# [0.07641221582889557, 0.9821000099182129]

# %%
test_img = test_images[6]
test_img = tf.expand_dims(test_img, axis=0)
pred = model.predict(test_img)

# %%
idx = pred.argmax()
print(f'Class: {idx}')
print(f'Probability: {pred[0][idx]:.4f}')
# Out:
# Class: 4
# Probability: 0.9745
